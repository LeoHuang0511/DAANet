# %%
import glob
dataset = "SENSE"
exp = "05-13_23-59_vgg_con10_SENSE_5e-05_0.0001"
device = ""
gpu = 2
backbone = ""

if device == "TWCC":
    gpu = 0

    root = "/home/leohuang0511"
else:
    root = "/nfs/home/leo0511/Research"
files = sorted(glob.glob(f"{root}/DutyMOFA/exp/{dataset}/{exp}/ep*"))
for file in files:
    print(f"python test_{dataset}.py --MODEL_PATH {file} --GPU_ID {gpu} ")
# Out:
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_10_iter_144000_mae_4.142_mse_8.464_seq_MAE_7.316_seq_MSE_11.130_WRAE_15.395_MIAE_1.408_MOAE_1.463.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_11_iter_168000_mae_4.542_mse_9.695_seq_MAE_7.938_seq_MSE_10.699_WRAE_16.843_MIAE_1.425_MOAE_1.431.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_1_iter_10000_mae_4.550_mse_6.954_seq_MAE_10.764_seq_MSE_15.259_WRAE_21.229_MIAE_1.512_MOAE_1.731.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_1_iter_12000_mae_3.026_mse_5.364_seq_MAE_12.728_seq_MSE_17.756_WRAE_23.569_MIAE_1.551_MOAE_1.769.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_1_iter_14000_mae_3.696_mse_6.831_seq_MAE_10.864_seq_MSE_15.286_WRAE_21.326_MIAE_1.459_MOAE_1.679.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_1_iter_2000_mae_7.999_mse_12.377_seq_MAE_66.833_seq_MSE_79.620_WRAE_135.408_MIAE_6.574_MOAE_6.384.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_1_iter_4000_mae_5.319_mse_8.572_seq_MAE_28.768_seq_MSE_33.832_WRAE_61.373_MIAE_2.993_MOAE_2.849.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_1_iter_6000_mae_6.814_mse_8.900_seq_MAE_14.584_seq_MSE_17.338_WRAE_33.380_MIAE_1.672_MOAE_1.653.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_1_iter_8000_mae_3.962_mse_6.445_seq_MAE_10.494_seq_MSE_13.294_WRAE_24.261_MIAE_1.483_MOAE_1.622.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_2_iter_28000_mae_3.943_mse_6.727_seq_MAE_11.118_seq_MSE_13.362_WRAE_25.408_MIAE_1.431_MOAE_1.593.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_3_iter_32000_mae_3.673_mse_6.543_seq_MAE_10.231_seq_MSE_13.488_WRAE_22.556_MIAE_1.514_MOAE_1.615.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_3_iter_34000_mae_4.737_mse_9.103_seq_MAE_10.721_seq_MSE_15.695_WRAE_20.407_MIAE_1.481_MOAE_1.576.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_3_iter_36000_mae_3.903_mse_7.809_seq_MAE_10.100_seq_MSE_14.315_WRAE_19.943_MIAE_1.436_MOAE_1.561.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_3_iter_40000_mae_3.647_mse_7.419_seq_MAE_9.938_seq_MSE_14.253_WRAE_19.835_MIAE_1.406_MOAE_1.544.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_3_iter_44000_mae_4.261_mse_8.991_seq_MAE_9.302_seq_MSE_13.368_WRAE_20.088_MIAE_1.490_MOAE_1.553.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_4_iter_50000_mae_3.873_mse_7.940_seq_MAE_8.834_seq_MSE_13.154_WRAE_17.513_MIAE_1.460_MOAE_1.542.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_4_iter_52000_mae_3.950_mse_8.307_seq_MAE_9.071_seq_MSE_12.498_WRAE_19.514_MIAE_1.461_MOAE_1.545.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_4_iter_56000_mae_3.829_mse_8.163_seq_MAE_8.351_seq_MSE_12.529_WRAE_17.358_MIAE_1.525_MOAE_1.554.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_4_iter_58000_mae_4.356_mse_9.466_seq_MAE_8.835_seq_MSE_11.523_WRAE_20.913_MIAE_1.521_MOAE_1.561.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_4_iter_60000_mae_4.126_mse_8.715_seq_MAE_9.260_seq_MSE_12.373_WRAE_21.008_MIAE_1.531_MOAE_1.527.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_5_iter_64000_mae_4.162_mse_9.199_seq_MAE_8.181_seq_MSE_11.497_WRAE_16.937_MIAE_1.441_MOAE_1.501.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_5_iter_74000_mae_3.814_mse_8.235_seq_MAE_8.382_seq_MSE_10.957_WRAE_19.318_MIAE_1.457_MOAE_1.480.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_6_iter_84000_mae_4.301_mse_8.918_seq_MAE_7.847_seq_MSE_10.918_WRAE_16.785_MIAE_1.407_MOAE_1.450.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_7_iter_104000_mae_4.485_mse_10.035_seq_MAE_8.914_seq_MSE_11.805_WRAE_19.522_MIAE_1.393_MOAE_1.451.pth --GPU_ID 2
# python test_SENSE.py --MODEL_PATH /nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/05-13_23-59_vgg_con10_SENSE_5e-05_0.0001/ep_7_iter_106000_mae_3.749_mse_8.015_seq_MAE_8.586_seq_MSE_13.541_WRAE_16.439_MIAE_1.532_MOAE_1.563.pth --GPU_ID 2

# %%
import torch
import argparse
from importlib import import_module


parser = argparse.ArgumentParser()
parser.add_argument('--EXP_NAME', type=str, default='')

parser.add_argument('--RESUME_PATH',type=str, default='')
parser.add_argument('--PRETRAIN_PATH',type=str, default='')
parser.add_argument('--FROZEN', default=False, action='store_true', help="frozen pretrained frontend weights")


parser.add_argument('--GPU_ID', type=str, default='0')
parser.add_argument('--SEED', type=int, default=3035)
parser.add_argument('--DATASET', type=str, default='HT21')
parser.add_argument('--TASK', type=str, default='FT')
parser.add_argument('--PRINT_FREQ', type=int, default=20)
parser.add_argument('--SAVE_VIS_FREQ', type=int, default=500)
parser.add_argument('--BACKBONE', type=str, default='vgg')


parser.add_argument('--LR_MIN', type=float, default=1e-6)
parser.add_argument('--LR_BASE', type=float, default=5e-5, help='density branch')
parser.add_argument('--LR_THRE', type=float, default=1e-4, help='mask branch')
parser.add_argument('--LR_DECAY', type=float, default=0.95)
parser.add_argument('--WEIGHT_DECAY', type=float, default=1e-5)
parser.add_argument('--WARMUP_EPOCH', type=int, default=3, help='number of epochs for warm up step in cosine annealing lr scheduler')
parser.add_argument('--MAX_EPOCH', type=int, default=20)
parser.add_argument('--WORKER', type=int, default=4)


parser.add_argument('--CON_WEIGHT', type=float, default=0.5)
parser.add_argument('--SCALE_WEIGHT', type=float, nargs='+', default=[2,0.1,0.01])
parser.add_argument('--CNT_WEIGHT', type=float, default=10)
parser.add_argument('--MASK_WEIGHT', type=float, default=1)
parser.add_argument('--IO_WEIGHT', type=float, default=1)




#_test or val
parser.add_argument('--VAL_FREQ', type=int, default=1000)
parser.add_argument('--VAL_START', type=int, default=1)
parser.add_argument('--VAL_BATCH_SIZE', type=int, default=1)



#_train
parser.add_argument('--TRAIN_SIZE', type=int, nargs='+', default=[768,1024])
parser.add_argument('--TRAIN_FRAME_INTERVALS', type=int, nargs='+', default=[40, 85])
parser.add_argument('--TRAIN_BATCH_SIZE', type=int, default=2)
parser.add_argument('--ROI_RADIUS', type=float, default=4.)
parser.add_argument('--FEATURE_SCALE', type=float, default=1/4.)
parser.add_argument('--GAUSSIAN_SIGMA', type=float, default=4)
parser.add_argument('--CONF_BLOCK_SIZE', type=int, default=16)




#_shift pretrain
parser.add_argument('--WIN_OFFSET_RANGE', type=int, nargs='+', default=[100,350])
parser.add_argument('--IMG_OFFSET_RANGE', type=int, nargs='+', default=[-100,100])


parser.add_argument('--DEN_FACTOR', type=float, default=200.)
parser.add_argument('--MEAN_STD', type=tuple, default=([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]))

# cfg = parser.parse_args()
cfg = parser.parse_known_args()[0]


# data_mode = cfg.DATASET
# datasetting = import_module(f'datasets.setting.{data_mode}')
# cfg_data = datasetting.cfg_data
cfg_data = cfg

# %%
import sys
sys.path.append('..')
from model.SMDCA import  SMDCANet

model = SMDCANet(cfg, cfg_data).Extractor.scale_loc_head
total = sum([param.nelement() for param in model.parameters()])
print("Number of parameter: %.2fM" % (total/1e6))
# Out:
# Number of parameter: 0.16M

# %%
import sys
sys.path.append('../../../')

from FMDC.model.video_crowd_count import  video_crowd_count
sys.path.append('./FMDC')


model = video_crowd_count(cfg, cfg_data)
total = sum([param.nelement() for param in model.parameters()])
print("Number of parameter: %.2fM" % (total/1e6))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [5], line 4
#       1 import sys
#       2 sys.path.append('../../../')
# ----> 4 from FMDC.model.video_crowd_count import  video_crowd_count
#       5 sys.path.append('./FMDC')
#       8 model = video_crowd_count(cfg, cfg_data)
#
# File ~/Research/SSSP/src/notebooks/../../../FMDC/model/video_crowd_count.py:5
#       3 import torch.nn.functional as F
#       4 import numpy as np
# ----> 5 from .VGG.VGG16_FPN import VGG16_FPN
#       6 from .optical_deformable_module import optical_deformable_alignment_module
#       7 from .unimatch import UniMatch
#
# File ~/Research/SSSP/src/notebooks/../../../FMDC/model/VGG/VGG16_FPN.py:4
#       2 import sys
#       3 import torch.nn.functional as F
# ----> 4 from misc.utils import *
#       5 from misc.layer import *
#       6 from torchsummary import summary
#
# ModuleNotFoundError: No module named 'misc'

# %%
import thop
from thop import profile 
input = torch.randn(4, 3, 768, 1024)
flops, params = profile(model, inputs=(input,))
print(flops)
print(params)
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.ConvTranspose2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.instancenorm.InstanceNorm2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 from thop import profile
#       3 input = torch.randn(4, 3, 768, 1024)
# ----> 4 flops, params = profile(model, inputs=(input,))
#       5 print(flops)
#       6 print(params)
#
# File ~/.local/lib/python3.10/site-packages/thop/profile.py:212, in profile(model, inputs, custom_ops, verbose, ret_layer_info, report_missing)
#     209 model.apply(add_hooks)
#     211 with torch.no_grad():
# --> 212     model(*inputs)
#     214 def dfs_count(module: nn.Module, prefix="\t") -> (int, int):
#     215     total_ops, total_params = module.total_ops.item(), 0
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1505, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1503     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1504 else:
# -> 1505     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1514, in Module._call_impl(self, *args, **kwargs)
#    1509 # If we don't have any hooks, we want to skip the rest of the logic in
#    1510 # this function, and just call forward.
#    1511 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1512         or _global_backward_pre_hooks or _global_backward_hooks
#    1513         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1514     return forward_call(*args, **kwargs)
#    1515 # Do not call functions when jit is used
#    1516 full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: video_crowd_count.forward() missing 2 required positional arguments: 'img_rgb' and 'target'

# %%
from torchvision import models
import torch.nn as nn

swin = models.swin_b(weights='Swin_B_Weights.IMAGENET1K_V1')
features = list(swin.features.children())
layer1 = nn.Sequential(*features[0:2])
layer2 = nn.Sequential(*features[2:4])
layer3 = nn.Sequential(*features[4:6])

# %%
import torch

x  = torch.zeros((4,3,768,1024))
x = layer1(x)
print(x.shape)
x = layer2(x)
print(x.shape)
x = layer3(x)
print(x.shape)
# Out:
# torch.Size([4, 192, 256, 128])
# torch.Size([4, 96, 128, 256])
# torch.Size([4, 48, 64, 512])

# %%
len(features)
# Out:
# 8

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np

# Creating dataset
np.random.seed(10)
data_1 = np.array([16.1,10.1,7.9,6.6,6.6,7.1,7.1,8.4,8.0,8.6,8.2,8.6])
data_2 = np.array([26.6,20.0,18.3,16.9,17.7,17.0,16.9,17.0,18.5,17.8,19.3,17.8,19.1])

data = [data_1, data_2]

fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(data, patch_artist = True,
				notch ='True', vert = 0)

colors = ['#0000FF', '#00FF00']

for patch, color in zip(bp['boxes'], colors):
	patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
	whisker.set(color ='#8B008B',
				linewidth = 1.5,
				linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
	cap.set(color ='#8B008B',
			linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
	median.set(color ='red',
			linewidth = 3)

# changing style of fliers
for flier in bp['fliers']:
	flier.set(marker ='D',
			color ='#e7298a',
			alpha = 0.5)
	
# x-axis labels
ax.set_yticklabels(['data_1', 'data_2'])

# Adding title 
plt.title("Customized box plot")

# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
	
# show plot
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)
bp = ax.violinplot(data, vert=0)

ax.set_yticklabels(['data_1', 'data_2'])

# Adding title 
plt.title("Customized box plot")

# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
	
# show plot
plt.show()
# Out:
# /tmp/ipykernel_258610/3645038855.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['data_1', 'data_2'])

# %%
import pandas as pd
from tensorboard.backend.event_processing import event_accumulator

def scale_to_array(path, key_name):
 
    #加载日志数据
    list = []
    ea=event_accumulator.EventAccumulator(path) 
    ea.Reload()
    print(ea.scalars.Keys())
    
    val_psnr=ea.scalars.Items(key_name)
    print(len(val_psnr))
    for i in val_psnr:
        list.append([i.step,i.value]) 
    return list
        
lam = scale_to_array('/nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/02-21_14-18_vgg__SENSE_5e-05_0.0001', 'dynamic_weight')
scale = scale_to_array('/nfs/home/leo0511/Research/DutyMOFA/exp/SENSE/02-21_14-18_vgg__SENSE_5e-05_0.0001', 'loss_den')
# Out:
# ['loss_den_overall', 'loss_den', 'loss_mask', 'loss_in', 'loss_out', 'loss_con', 'dynamic_weight', 'base_lr', 'thre_lr', 'mae', 'mse', 'seqMAE', 'seqMSE', 'WRAE', 'MIAE', 'MOAE']
# 10000
# ['loss_den_overall', 'loss_den', 'loss_mask', 'loss_in', 'loss_out', 'loss_con', 'dynamic_weight', 'base_lr', 'thre_lr', 'mae', 'mse', 'seqMAE', 'seqMSE', 'WRAE', 'MIAE', 'MOAE']
# 10000

# %%
import matplotlib as mat
import matplotlib.pyplot as plt
import numpy as np

import scienceplots
import matplotlib.font_manager as font_manager


plt.style.use(['science', 'no-latex', 'ieee'])
lam = np.array(lam)
scale = np.array(scale)
lam = np.insert(lam,0,[0,0],0)
scale = np.insert(scale,0,[0,0.3],0)

# font = font_manager.FontProperties(;family'='Times New Roman')
plt.rc('font', family='Times New Roman')
# Example: plot cos(x), sin(x), and sinc(x) in the same figure
# plt.xscale('log')
plt.xlim([0,1500])

plt.xlabel('Iteration ($i$)')
plt.ylabel('Value')

plt.plot(lam[:,0], lam[:,1], 'red')   # black dashed line, with "+" markers
plt.plot(scale[:,0], scale[:,1], 'green')     # green dimonds (no line)
plt.legend(['$\lambda_i$','$\epsilon_i$'],prop={'family':'Times New Roman'})
plt.savefig('../ECCV_SOFA-lambfa.pdf')
plt.show()

# %%
import matplotlib as mat
import matplotlib.pyplot as plt
import numpy as np

import scienceplots
import matplotlib.font_manager as font_manager


plt.style.use(['science', 'no-latex', 'ieee'])
hyper = 'Interval (s)'
metric = "MAE"
sofa = np.array([9.1,
8.4,
7.9,
7.7,
6.6,
7.2,
6.6,
7.2,
7.1,
7.4,
7.1,
8.2,
7.3,
7.9,
8.4,
8.2])

fmdc = np.array([20,
19.1,
18.3,
18.1,
16.9,
16.6,
16.7,
17.7,
17.0,
16.9,
17.8,
18.0,
17.0,
17.7,
18.5,
19.6])

xticks = [1.0,
1.2,
1.4,
1.6,
1.8,
2.0,
2.2,
2.4,
2.6,
2.8,
3.0,
3.2,
3.4,
3.6,
3.8,
4.0]

sofa_mean= np.around(np.mean(sofa),1)
sofa_var = np.around(np.var(sofa),1)
fmdc_mean = np.around(np.mean(fmdc),1)
fmdc_var = np.around(np.var(fmdc),1)

gap=0.2

# %%
# plt.xticks([xticks])


# font = font_manager.FontProperties(;family'='Times New Roman')
plt.rc('font', family='Times New Roman')
# Example: plot cos(x), sin(x), and sinc(x) in the same figure
# plt.xscale('log')

plt.ylabel(metric)

# for a,b,c in zip(sofa, fmdc, xticks):
#     plt.text(c,a,a,ha='center',va='bottom',fontsize=6)
#     plt.text(c,b,b,ha='center',va='bottom',fontsize=6)
    # plt.text(d,c,c,ha='center',va='bottom',fontsize=6)

plt.ylim([0,30])
plt.xlim([0.8,xticks[-1]+gap])

plt.plot(xticks, sofa,'ro-' ,markersize=2)   # black dashed line, with "+" markers
plt.plot(xticks, fmdc, 'gv-',markersize=2)   
# plt.plot(xticks, wrae, 'blue')     # green dimonds (no line)
  # green dimonds (no line)
plt.legend([f'Ours ($\mu={sofa_mean}, \sigma^2={sofa_var}$)',f'FMDC ($\mu={fmdc_mean}, \sigma^2={fmdc_var}$)'],prop={'family':'Times New Roman'},loc='upper left')
plt.xlabel(f'{hyper}')
plt.savefig('../ECCV_SOFA-'+metric+hyper+'.pdf')
plt.show()

# %%
import torch

path = "/nfs/home/leo0511/Research/SOFA/exp/pretrained/SenseCrowd.pth"

model_dict = torch.load(path)
new_model_dict = {}

dict=[]

for k, v in model_dict["net"].items():
    new_key = k.replace("SOFANet", "DAANet")
    # new_key = k.replace("confidence_predict_layer","ASAM")
    new_model_dict[new_key]= v
    print(k)
    print(new_key)

torch.save(new_model_dict,path)
# Out:
# Extractor.layer1.0.weight
# Extractor.layer1.0.weight
# Extractor.layer1.0.bias
# Extractor.layer1.0.bias
# Extractor.layer1.1.weight
# Extractor.layer1.1.weight
# Extractor.layer1.1.bias
# Extractor.layer1.1.bias
# Extractor.layer1.1.running_mean
# Extractor.layer1.1.running_mean
# Extractor.layer1.1.running_var
# Extractor.layer1.1.running_var
# Extractor.layer1.1.num_batches_tracked
# Extractor.layer1.1.num_batches_tracked
# Extractor.layer1.3.weight
# Extractor.layer1.3.weight
# Extractor.layer1.3.bias
# Extractor.layer1.3.bias
# Extractor.layer1.4.weight
# Extractor.layer1.4.weight
# Extractor.layer1.4.bias
# Extractor.layer1.4.bias
# Extractor.layer1.4.running_mean
# Extractor.layer1.4.running_mean
# Extractor.layer1.4.running_var
# Extractor.layer1.4.running_var
# Extractor.layer1.4.num_batches_tracked
# Extractor.layer1.4.num_batches_tracked
# Extractor.layer1.7.weight
# Extractor.layer1.7.weight
# Extractor.layer1.7.bias
# Extractor.layer1.7.bias
# Extractor.layer1.8.weight
# Extractor.layer1.8.weight
# Extractor.layer1.8.bias
# Extractor.layer1.8.bias
# Extractor.layer1.8.running_mean
# Extractor.layer1.8.running_mean
# Extractor.layer1.8.running_var
# Extractor.layer1.8.running_var
# Extractor.layer1.8.num_batches_tracked
# Extractor.layer1.8.num_batches_tracked
# Extractor.layer1.10.weight
# Extractor.layer1.10.weight
# Extractor.layer1.10.bias
# Extractor.layer1.10.bias
# Extractor.layer1.11.weight
# Extractor.layer1.11.weight
# Extractor.layer1.11.bias
# Extractor.layer1.11.bias
# Extractor.layer1.11.running_mean
# Extractor.layer1.11.running_mean
# Extractor.layer1.11.running_var
# Extractor.layer1.11.running_var
# Extractor.layer1.11.num_batches_tracked
# Extractor.layer1.11.num_batches_tracked
# Extractor.layer1.14.weight
# Extractor.layer1.14.weight
# Extractor.layer1.14.bias
# Extractor.layer1.14.bias
# Extractor.layer1.15.weight
# Extractor.layer1.15.weight
# Extractor.layer1.15.bias
# Extractor.layer1.15.bias
# Extractor.layer1.15.running_mean
# Extractor.layer1.15.running_mean
# Extractor.layer1.15.running_var
# Extractor.layer1.15.running_var
# Extractor.layer1.15.num_batches_tracked
# Extractor.layer1.15.num_batches_tracked
# Extractor.layer1.17.weight
# Extractor.layer1.17.weight
# Extractor.layer1.17.bias
# Extractor.layer1.17.bias
# Extractor.layer1.18.weight
# Extractor.layer1.18.weight
# Extractor.layer1.18.bias
# Extractor.layer1.18.bias
# Extractor.layer1.18.running_mean
# Extractor.layer1.18.running_mean
# Extractor.layer1.18.running_var
# Extractor.layer1.18.running_var
# Extractor.layer1.18.num_batches_tracked
# Extractor.layer1.18.num_batches_tracked
# Extractor.layer1.20.weight
# Extractor.layer1.20.weight
# Extractor.layer1.20.bias
# Extractor.layer1.20.bias
# Extractor.layer1.21.weight
# Extractor.layer1.21.weight
# Extractor.layer1.21.bias
# Extractor.layer1.21.bias
# Extractor.layer1.21.running_mean
# Extractor.layer1.21.running_mean
# Extractor.layer1.21.running_var
# Extractor.layer1.21.running_var
# Extractor.layer1.21.num_batches_tracked
# Extractor.layer1.21.num_batches_tracked
# Extractor.layer2.1.weight
# Extractor.layer2.1.weight
# Extractor.layer2.1.bias
# Extractor.layer2.1.bias
# Extractor.layer2.2.weight
# Extractor.layer2.2.weight
# Extractor.layer2.2.bias
# Extractor.layer2.2.bias
# Extractor.layer2.2.running_mean
# Extractor.layer2.2.running_mean
# Extractor.layer2.2.running_var
# Extractor.layer2.2.running_var
# Extractor.layer2.2.num_batches_tracked
# Extractor.layer2.2.num_batches_tracked
# Extractor.layer2.4.weight
# Extractor.layer2.4.weight
# Extractor.layer2.4.bias
# Extractor.layer2.4.bias
# Extractor.layer2.5.weight
# Extractor.layer2.5.weight
# Extractor.layer2.5.bias
# Extractor.layer2.5.bias
# Extractor.layer2.5.running_mean
# Extractor.layer2.5.running_mean
# Extractor.layer2.5.running_var
# Extractor.layer2.5.running_var
# Extractor.layer2.5.num_batches_tracked
# Extractor.layer2.5.num_batches_tracked
# Extractor.layer2.7.weight
# Extractor.layer2.7.weight
# Extractor.layer2.7.bias
# Extractor.layer2.7.bias
# Extractor.layer2.8.weight
# Extractor.layer2.8.weight
# Extractor.layer2.8.bias
# Extractor.layer2.8.bias
# Extractor.layer2.8.running_mean
# Extractor.layer2.8.running_mean
# Extractor.layer2.8.running_var
# Extractor.layer2.8.running_var
# Extractor.layer2.8.num_batches_tracked
# Extractor.layer2.8.num_batches_tracked
# Extractor.layer3.1.weight
# Extractor.layer3.1.weight
# Extractor.layer3.1.bias
# Extractor.layer3.1.bias
# Extractor.layer3.2.weight
# Extractor.layer3.2.weight
# Extractor.layer3.2.bias
# Extractor.layer3.2.bias
# Extractor.layer3.2.running_mean
# Extractor.layer3.2.running_mean
# Extractor.layer3.2.running_var
# Extractor.layer3.2.running_var
# Extractor.layer3.2.num_batches_tracked
# Extractor.layer3.2.num_batches_tracked
# Extractor.layer3.4.weight
# Extractor.layer3.4.weight
# Extractor.layer3.4.bias
# Extractor.layer3.4.bias
# Extractor.layer3.5.weight
# Extractor.layer3.5.weight
# Extractor.layer3.5.bias
# Extractor.layer3.5.bias
# Extractor.layer3.5.running_mean
# Extractor.layer3.5.running_mean
# Extractor.layer3.5.running_var
# Extractor.layer3.5.running_var
# Extractor.layer3.5.num_batches_tracked
# Extractor.layer3.5.num_batches_tracked
# Extractor.layer3.7.weight
# Extractor.layer3.7.weight
# Extractor.layer3.7.bias
# Extractor.layer3.7.bias
# Extractor.layer3.8.weight
# Extractor.layer3.8.weight
# Extractor.layer3.8.bias
# Extractor.layer3.8.bias
# Extractor.layer3.8.running_mean
# Extractor.layer3.8.running_mean
# Extractor.layer3.8.running_var
# Extractor.layer3.8.running_var
# Extractor.layer3.8.num_batches_tracked
# Extractor.layer3.8.num_batches_tracked
# Extractor.neck.lateral_convs.0.conv.weight
# Extractor.neck.lateral_convs.0.conv.weight
# Extractor.neck.lateral_convs.0.bn.weight
# Extractor.neck.lateral_convs.0.bn.weight
# Extractor.neck.lateral_convs.0.bn.bias
# Extractor.neck.lateral_convs.0.bn.bias
# Extractor.neck.lateral_convs.0.bn.running_mean
# Extractor.neck.lateral_convs.0.bn.running_mean
# Extractor.neck.lateral_convs.0.bn.running_var
# Extractor.neck.lateral_convs.0.bn.running_var
# Extractor.neck.lateral_convs.0.bn.num_batches_tracked
# Extractor.neck.lateral_convs.0.bn.num_batches_tracked
# Extractor.neck.lateral_convs.1.conv.weight
# Extractor.neck.lateral_convs.1.conv.weight
# Extractor.neck.lateral_convs.1.bn.weight
# Extractor.neck.lateral_convs.1.bn.weight
# Extractor.neck.lateral_convs.1.bn.bias
# Extractor.neck.lateral_convs.1.bn.bias
# Extractor.neck.lateral_convs.1.bn.running_mean
# Extractor.neck.lateral_convs.1.bn.running_mean
# Extractor.neck.lateral_convs.1.bn.running_var
# Extractor.neck.lateral_convs.1.bn.running_var
# Extractor.neck.lateral_convs.1.bn.num_batches_tracked
# Extractor.neck.lateral_convs.1.bn.num_batches_tracked
# Extractor.neck.lateral_convs.2.conv.weight
# Extractor.neck.lateral_convs.2.conv.weight
# Extractor.neck.lateral_convs.2.bn.weight
# Extractor.neck.lateral_convs.2.bn.weight
# Extractor.neck.lateral_convs.2.bn.bias
# Extractor.neck.lateral_convs.2.bn.bias
# Extractor.neck.lateral_convs.2.bn.running_mean
# Extractor.neck.lateral_convs.2.bn.running_mean
# Extractor.neck.lateral_convs.2.bn.running_var
# Extractor.neck.lateral_convs.2.bn.running_var
# Extractor.neck.lateral_convs.2.bn.num_batches_tracked
# Extractor.neck.lateral_convs.2.bn.num_batches_tracked
# Extractor.neck.fpn_convs.0.conv.weight
# Extractor.neck.fpn_convs.0.conv.weight
# Extractor.neck.fpn_convs.0.bn.weight
# Extractor.neck.fpn_convs.0.bn.weight
# Extractor.neck.fpn_convs.0.bn.bias
# Extractor.neck.fpn_convs.0.bn.bias
# Extractor.neck.fpn_convs.0.bn.running_mean
# Extractor.neck.fpn_convs.0.bn.running_mean
# Extractor.neck.fpn_convs.0.bn.running_var
# Extractor.neck.fpn_convs.0.bn.running_var
# Extractor.neck.fpn_convs.0.bn.num_batches_tracked
# Extractor.neck.fpn_convs.0.bn.num_batches_tracked
# Extractor.neck.fpn_convs.1.conv.weight
# Extractor.neck.fpn_convs.1.conv.weight
# Extractor.neck.fpn_convs.1.bn.weight
# Extractor.neck.fpn_convs.1.bn.weight
# Extractor.neck.fpn_convs.1.bn.bias
# Extractor.neck.fpn_convs.1.bn.bias
# Extractor.neck.fpn_convs.1.bn.running_mean
# Extractor.neck.fpn_convs.1.bn.running_mean
# Extractor.neck.fpn_convs.1.bn.running_var
# Extractor.neck.fpn_convs.1.bn.running_var
# Extractor.neck.fpn_convs.1.bn.num_batches_tracked
# Extractor.neck.fpn_convs.1.bn.num_batches_tracked
# Extractor.neck.fpn_convs.2.conv.weight
# Extractor.neck.fpn_convs.2.conv.weight
# Extractor.neck.fpn_convs.2.bn.weight
# Extractor.neck.fpn_convs.2.bn.weight
# Extractor.neck.fpn_convs.2.bn.bias
# Extractor.neck.fpn_convs.2.bn.bias
# Extractor.neck.fpn_convs.2.bn.running_mean
# Extractor.neck.fpn_convs.2.bn.running_mean
# Extractor.neck.fpn_convs.2.bn.running_var
# Extractor.neck.fpn_convs.2.bn.running_var
# Extractor.neck.fpn_convs.2.bn.num_batches_tracked
# Extractor.neck.fpn_convs.2.bn.num_batches_tracked
# Extractor.neck2f.lateral_convs.0.conv.weight
# Extractor.neck2f.lateral_convs.0.conv.weight
# Extractor.neck2f.lateral_convs.0.bn.weight
# Extractor.neck2f.lateral_convs.0.bn.weight
# Extractor.neck2f.lateral_convs.0.bn.bias
# Extractor.neck2f.lateral_convs.0.bn.bias
# Extractor.neck2f.lateral_convs.0.bn.running_mean
# Extractor.neck2f.lateral_convs.0.bn.running_mean
# Extractor.neck2f.lateral_convs.0.bn.running_var
# Extractor.neck2f.lateral_convs.0.bn.running_var
# Extractor.neck2f.lateral_convs.0.bn.num_batches_tracked
# Extractor.neck2f.lateral_convs.0.bn.num_batches_tracked
# Extractor.neck2f.lateral_convs.1.conv.weight
# Extractor.neck2f.lateral_convs.1.conv.weight
# Extractor.neck2f.lateral_convs.1.bn.weight
# Extractor.neck2f.lateral_convs.1.bn.weight
# Extractor.neck2f.lateral_convs.1.bn.bias
# Extractor.neck2f.lateral_convs.1.bn.bias
# Extractor.neck2f.lateral_convs.1.bn.running_mean
# Extractor.neck2f.lateral_convs.1.bn.running_mean
# Extractor.neck2f.lateral_convs.1.bn.running_var
# Extractor.neck2f.lateral_convs.1.bn.running_var
# Extractor.neck2f.lateral_convs.1.bn.num_batches_tracked
# Extractor.neck2f.lateral_convs.1.bn.num_batches_tracked
# Extractor.neck2f.lateral_convs.2.conv.weight
# Extractor.neck2f.lateral_convs.2.conv.weight
# Extractor.neck2f.lateral_convs.2.bn.weight
# Extractor.neck2f.lateral_convs.2.bn.weight
# Extractor.neck2f.lateral_convs.2.bn.bias
# Extractor.neck2f.lateral_convs.2.bn.bias
# Extractor.neck2f.lateral_convs.2.bn.running_mean
# Extractor.neck2f.lateral_convs.2.bn.running_mean
# Extractor.neck2f.lateral_convs.2.bn.running_var
# Extractor.neck2f.lateral_convs.2.bn.running_var
# Extractor.neck2f.lateral_convs.2.bn.num_batches_tracked
# Extractor.neck2f.lateral_convs.2.bn.num_batches_tracked
# Extractor.neck2f.fpn_convs.0.conv.weight
# Extractor.neck2f.fpn_convs.0.conv.weight
# Extractor.neck2f.fpn_convs.0.bn.weight
# Extractor.neck2f.fpn_convs.0.bn.weight
# Extractor.neck2f.fpn_convs.0.bn.bias
# Extractor.neck2f.fpn_convs.0.bn.bias
# Extractor.neck2f.fpn_convs.0.bn.running_mean
# Extractor.neck2f.fpn_convs.0.bn.running_mean
# Extractor.neck2f.fpn_convs.0.bn.running_var
# Extractor.neck2f.fpn_convs.0.bn.running_var
# Extractor.neck2f.fpn_convs.0.bn.num_batches_tracked
# Extractor.neck2f.fpn_convs.0.bn.num_batches_tracked
# Extractor.neck2f.fpn_convs.1.conv.weight
# Extractor.neck2f.fpn_convs.1.conv.weight
# Extractor.neck2f.fpn_convs.1.bn.weight
# Extractor.neck2f.fpn_convs.1.bn.weight
# Extractor.neck2f.fpn_convs.1.bn.bias
# Extractor.neck2f.fpn_convs.1.bn.bias
# Extractor.neck2f.fpn_convs.1.bn.running_mean
# Extractor.neck2f.fpn_convs.1.bn.running_mean
# Extractor.neck2f.fpn_convs.1.bn.running_var
# Extractor.neck2f.fpn_convs.1.bn.running_var
# Extractor.neck2f.fpn_convs.1.bn.num_batches_tracked
# Extractor.neck2f.fpn_convs.1.bn.num_batches_tracked
# Extractor.neck2f.fpn_convs.2.conv.weight
# Extractor.neck2f.fpn_convs.2.conv.weight
# Extractor.neck2f.fpn_convs.2.bn.weight
# Extractor.neck2f.fpn_convs.2.bn.weight
# Extractor.neck2f.fpn_convs.2.bn.bias
# Extractor.neck2f.fpn_convs.2.bn.bias
# Extractor.neck2f.fpn_convs.2.bn.running_mean
# Extractor.neck2f.fpn_convs.2.bn.running_mean
# Extractor.neck2f.fpn_convs.2.bn.running_var
# Extractor.neck2f.fpn_convs.2.bn.running_var
# Extractor.neck2f.fpn_convs.2.bn.num_batches_tracked
# Extractor.neck2f.fpn_convs.2.bn.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.1.model.0.conv.weight
# Extractor.scale_loc_bottleneck.0.1.model.0.conv.weight
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.weight
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.weight
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.bias
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.bias
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.1.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.1.model.1.conv.weight
# Extractor.scale_loc_bottleneck.0.1.model.1.conv.weight
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.weight
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.weight
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.bias
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.bias
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.1.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.1.model.2.conv.weight
# Extractor.scale_loc_bottleneck.0.1.model.2.conv.weight
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.weight
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.weight
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.bias
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.bias
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.1.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.1.downsample.conv.weight
# Extractor.scale_loc_bottleneck.0.1.downsample.conv.weight
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.weight
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.weight
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.bias
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.bias
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.running_mean
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.running_mean
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.running_var
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.running_var
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.1.downsample.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.2.model.0.conv.weight
# Extractor.scale_loc_bottleneck.0.2.model.0.conv.weight
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.weight
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.weight
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.bias
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.bias
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.2.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.2.model.1.conv.weight
# Extractor.scale_loc_bottleneck.0.2.model.1.conv.weight
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.weight
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.weight
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.bias
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.bias
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.2.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.2.model.2.conv.weight
# Extractor.scale_loc_bottleneck.0.2.model.2.conv.weight
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.weight
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.weight
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.bias
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.bias
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.0.2.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.1.model.0.conv.weight
# Extractor.scale_loc_bottleneck.1.1.model.0.conv.weight
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.weight
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.weight
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.bias
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.bias
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.1.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.1.model.1.conv.weight
# Extractor.scale_loc_bottleneck.1.1.model.1.conv.weight
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.weight
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.weight
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.bias
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.bias
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.1.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.1.model.2.conv.weight
# Extractor.scale_loc_bottleneck.1.1.model.2.conv.weight
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.weight
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.weight
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.bias
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.bias
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.1.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.1.downsample.conv.weight
# Extractor.scale_loc_bottleneck.1.1.downsample.conv.weight
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.weight
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.weight
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.bias
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.bias
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.running_mean
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.running_mean
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.running_var
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.running_var
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.1.downsample.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.2.model.0.conv.weight
# Extractor.scale_loc_bottleneck.1.2.model.0.conv.weight
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.weight
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.weight
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.bias
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.bias
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.2.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.2.model.1.conv.weight
# Extractor.scale_loc_bottleneck.1.2.model.1.conv.weight
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.weight
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.weight
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.bias
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.bias
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.2.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.2.model.2.conv.weight
# Extractor.scale_loc_bottleneck.1.2.model.2.conv.weight
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.weight
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.weight
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.bias
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.bias
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.1.2.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.1.model.0.conv.weight
# Extractor.scale_loc_bottleneck.2.1.model.0.conv.weight
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.weight
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.weight
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.bias
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.bias
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.1.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.1.model.1.conv.weight
# Extractor.scale_loc_bottleneck.2.1.model.1.conv.weight
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.weight
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.weight
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.bias
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.bias
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.1.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.1.model.2.conv.weight
# Extractor.scale_loc_bottleneck.2.1.model.2.conv.weight
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.weight
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.weight
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.bias
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.bias
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.1.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.1.downsample.conv.weight
# Extractor.scale_loc_bottleneck.2.1.downsample.conv.weight
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.weight
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.weight
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.bias
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.bias
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.running_mean
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.running_mean
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.running_var
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.running_var
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.1.downsample.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.2.model.0.conv.weight
# Extractor.scale_loc_bottleneck.2.2.model.0.conv.weight
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.weight
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.weight
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.bias
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.bias
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.running_mean
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.running_var
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.2.model.0.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.2.model.1.conv.weight
# Extractor.scale_loc_bottleneck.2.2.model.1.conv.weight
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.weight
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.weight
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.bias
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.bias
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.running_mean
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.running_var
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.2.model.1.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.2.model.2.conv.weight
# Extractor.scale_loc_bottleneck.2.2.model.2.conv.weight
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.weight
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.weight
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.bias
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.bias
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.running_mean
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.running_var
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.num_batches_tracked
# Extractor.scale_loc_bottleneck.2.2.model.2.norm.num_batches_tracked
# Extractor.scale_loc_head.0.0.weight
# Extractor.scale_loc_head.0.0.weight
# Extractor.scale_loc_head.0.1.weight
# Extractor.scale_loc_head.0.1.weight
# Extractor.scale_loc_head.0.1.bias
# Extractor.scale_loc_head.0.1.bias
# Extractor.scale_loc_head.0.1.running_mean
# Extractor.scale_loc_head.0.1.running_mean
# Extractor.scale_loc_head.0.1.running_var
# Extractor.scale_loc_head.0.1.running_var
# Extractor.scale_loc_head.0.1.num_batches_tracked
# Extractor.scale_loc_head.0.1.num_batches_tracked
# Extractor.scale_loc_head.0.3.weight
# Extractor.scale_loc_head.0.3.weight
# Extractor.scale_loc_head.0.3.bias
# Extractor.scale_loc_head.0.3.bias
# Extractor.scale_loc_head.0.4.weight
# Extractor.scale_loc_head.0.4.weight
# Extractor.scale_loc_head.0.4.bias
# Extractor.scale_loc_head.0.4.bias
# Extractor.scale_loc_head.0.4.running_mean
# Extractor.scale_loc_head.0.4.running_mean
# Extractor.scale_loc_head.0.4.running_var
# Extractor.scale_loc_head.0.4.running_var
# Extractor.scale_loc_head.0.4.num_batches_tracked
# Extractor.scale_loc_head.0.4.num_batches_tracked
# Extractor.scale_loc_head.0.6.weight
# Extractor.scale_loc_head.0.6.weight
# Extractor.scale_loc_head.0.7.weight
# Extractor.scale_loc_head.0.7.weight
# Extractor.scale_loc_head.0.7.bias
# Extractor.scale_loc_head.0.7.bias
# Extractor.scale_loc_head.0.7.running_mean
# Extractor.scale_loc_head.0.7.running_mean
# Extractor.scale_loc_head.0.7.running_var
# Extractor.scale_loc_head.0.7.running_var
# Extractor.scale_loc_head.0.7.num_batches_tracked
# Extractor.scale_loc_head.0.7.num_batches_tracked
# Extractor.scale_loc_head.0.9.weight
# Extractor.scale_loc_head.0.9.weight
# Extractor.scale_loc_head.0.9.bias
# Extractor.scale_loc_head.0.9.bias
# Extractor.scale_loc_head.1.0.weight
# Extractor.scale_loc_head.1.0.weight
# Extractor.scale_loc_head.1.1.weight
# Extractor.scale_loc_head.1.1.weight
# Extractor.scale_loc_head.1.1.bias
# Extractor.scale_loc_head.1.1.bias
# Extractor.scale_loc_head.1.1.running_mean
# Extractor.scale_loc_head.1.1.running_mean
# Extractor.scale_loc_head.1.1.running_var
# Extractor.scale_loc_head.1.1.running_var
# Extractor.scale_loc_head.1.1.num_batches_tracked
# Extractor.scale_loc_head.1.1.num_batches_tracked
# Extractor.scale_loc_head.1.3.weight
# Extractor.scale_loc_head.1.3.weight
# Extractor.scale_loc_head.1.3.bias
# Extractor.scale_loc_head.1.3.bias
# Extractor.scale_loc_head.1.4.weight
# Extractor.scale_loc_head.1.4.weight
# Extractor.scale_loc_head.1.4.bias
# Extractor.scale_loc_head.1.4.bias
# Extractor.scale_loc_head.1.4.running_mean
# Extractor.scale_loc_head.1.4.running_mean
# Extractor.scale_loc_head.1.4.running_var
# Extractor.scale_loc_head.1.4.running_var
# Extractor.scale_loc_head.1.4.num_batches_tracked
# Extractor.scale_loc_head.1.4.num_batches_tracked
# Extractor.scale_loc_head.1.6.weight
# Extractor.scale_loc_head.1.6.weight
# Extractor.scale_loc_head.1.7.weight
# Extractor.scale_loc_head.1.7.weight
# Extractor.scale_loc_head.1.7.bias
# Extractor.scale_loc_head.1.7.bias
# Extractor.scale_loc_head.1.7.running_mean
# Extractor.scale_loc_head.1.7.running_mean
# Extractor.scale_loc_head.1.7.running_var
# Extractor.scale_loc_head.1.7.running_var
# Extractor.scale_loc_head.1.7.num_batches_tracked
# Extractor.scale_loc_head.1.7.num_batches_tracked
# Extractor.scale_loc_head.1.9.weight
# Extractor.scale_loc_head.1.9.weight
# Extractor.scale_loc_head.1.9.bias
# Extractor.scale_loc_head.1.9.bias
# Extractor.scale_loc_head.2.0.weight
# Extractor.scale_loc_head.2.0.weight
# Extractor.scale_loc_head.2.1.weight
# Extractor.scale_loc_head.2.1.weight
# Extractor.scale_loc_head.2.1.bias
# Extractor.scale_loc_head.2.1.bias
# Extractor.scale_loc_head.2.1.running_mean
# Extractor.scale_loc_head.2.1.running_mean
# Extractor.scale_loc_head.2.1.running_var
# Extractor.scale_loc_head.2.1.running_var
# Extractor.scale_loc_head.2.1.num_batches_tracked
# Extractor.scale_loc_head.2.1.num_batches_tracked
# Extractor.scale_loc_head.2.3.weight
# Extractor.scale_loc_head.2.3.weight
# Extractor.scale_loc_head.2.3.bias
# Extractor.scale_loc_head.2.3.bias
# Extractor.scale_loc_head.2.4.weight
# Extractor.scale_loc_head.2.4.weight
# Extractor.scale_loc_head.2.4.bias
# Extractor.scale_loc_head.2.4.bias
# Extractor.scale_loc_head.2.4.running_mean
# Extractor.scale_loc_head.2.4.running_mean
# Extractor.scale_loc_head.2.4.running_var
# Extractor.scale_loc_head.2.4.running_var
# Extractor.scale_loc_head.2.4.num_batches_tracked
# Extractor.scale_loc_head.2.4.num_batches_tracked
# Extractor.scale_loc_head.2.6.weight
# Extractor.scale_loc_head.2.6.weight
# Extractor.scale_loc_head.2.7.weight
# Extractor.scale_loc_head.2.7.weight
# Extractor.scale_loc_head.2.7.bias
# Extractor.scale_loc_head.2.7.bias
# Extractor.scale_loc_head.2.7.running_mean
# Extractor.scale_loc_head.2.7.running_mean
# Extractor.scale_loc_head.2.7.running_var
# Extractor.scale_loc_head.2.7.running_var
# Extractor.scale_loc_head.2.7.num_batches_tracked
# Extractor.scale_loc_head.2.7.num_batches_tracked
# Extractor.scale_loc_head.2.9.weight
# Extractor.scale_loc_head.2.9.weight
# Extractor.scale_loc_head.2.9.bias
# Extractor.scale_loc_head.2.9.bias
# deformable_alignment.feature_head.0.1.model.0.conv.weight
# deformable_alignment.feature_head.0.1.model.0.conv.weight
# deformable_alignment.feature_head.0.1.model.0.norm.weight
# deformable_alignment.feature_head.0.1.model.0.norm.weight
# deformable_alignment.feature_head.0.1.model.0.norm.bias
# deformable_alignment.feature_head.0.1.model.0.norm.bias
# deformable_alignment.feature_head.0.1.model.0.norm.running_mean
# deformable_alignment.feature_head.0.1.model.0.norm.running_mean
# deformable_alignment.feature_head.0.1.model.0.norm.running_var
# deformable_alignment.feature_head.0.1.model.0.norm.running_var
# deformable_alignment.feature_head.0.1.model.0.norm.num_batches_tracked
# deformable_alignment.feature_head.0.1.model.0.norm.num_batches_tracked
# deformable_alignment.feature_head.0.1.model.1.conv.weight
# deformable_alignment.feature_head.0.1.model.1.conv.weight
# deformable_alignment.feature_head.0.1.model.1.norm.weight
# deformable_alignment.feature_head.0.1.model.1.norm.weight
# deformable_alignment.feature_head.0.1.model.1.norm.bias
# deformable_alignment.feature_head.0.1.model.1.norm.bias
# deformable_alignment.feature_head.0.1.model.1.norm.running_mean
# deformable_alignment.feature_head.0.1.model.1.norm.running_mean
# deformable_alignment.feature_head.0.1.model.1.norm.running_var
# deformable_alignment.feature_head.0.1.model.1.norm.running_var
# deformable_alignment.feature_head.0.1.model.1.norm.num_batches_tracked
# deformable_alignment.feature_head.0.1.model.1.norm.num_batches_tracked
# deformable_alignment.feature_head.0.1.model.2.conv.weight
# deformable_alignment.feature_head.0.1.model.2.conv.weight
# deformable_alignment.feature_head.0.1.model.2.norm.weight
# deformable_alignment.feature_head.0.1.model.2.norm.weight
# deformable_alignment.feature_head.0.1.model.2.norm.bias
# deformable_alignment.feature_head.0.1.model.2.norm.bias
# deformable_alignment.feature_head.0.1.model.2.norm.running_mean
# deformable_alignment.feature_head.0.1.model.2.norm.running_mean
# deformable_alignment.feature_head.0.1.model.2.norm.running_var
# deformable_alignment.feature_head.0.1.model.2.norm.running_var
# deformable_alignment.feature_head.0.1.model.2.norm.num_batches_tracked
# deformable_alignment.feature_head.0.1.model.2.norm.num_batches_tracked
# deformable_alignment.feature_head.0.2.weight
# deformable_alignment.feature_head.0.2.weight
# deformable_alignment.feature_head.0.3.weight
# deformable_alignment.feature_head.0.3.weight
# deformable_alignment.feature_head.0.3.bias
# deformable_alignment.feature_head.0.3.bias
# deformable_alignment.feature_head.0.3.running_mean
# deformable_alignment.feature_head.0.3.running_mean
# deformable_alignment.feature_head.0.3.running_var
# deformable_alignment.feature_head.0.3.running_var
# deformable_alignment.feature_head.0.3.num_batches_tracked
# deformable_alignment.feature_head.0.3.num_batches_tracked
# deformable_alignment.feature_head.0.5.weight
# deformable_alignment.feature_head.0.5.weight
# deformable_alignment.feature_head.0.5.bias
# deformable_alignment.feature_head.0.5.bias
# deformable_alignment.feature_head.1.1.model.0.conv.weight
# deformable_alignment.feature_head.1.1.model.0.conv.weight
# deformable_alignment.feature_head.1.1.model.0.norm.weight
# deformable_alignment.feature_head.1.1.model.0.norm.weight
# deformable_alignment.feature_head.1.1.model.0.norm.bias
# deformable_alignment.feature_head.1.1.model.0.norm.bias
# deformable_alignment.feature_head.1.1.model.0.norm.running_mean
# deformable_alignment.feature_head.1.1.model.0.norm.running_mean
# deformable_alignment.feature_head.1.1.model.0.norm.running_var
# deformable_alignment.feature_head.1.1.model.0.norm.running_var
# deformable_alignment.feature_head.1.1.model.0.norm.num_batches_tracked
# deformable_alignment.feature_head.1.1.model.0.norm.num_batches_tracked
# deformable_alignment.feature_head.1.1.model.1.conv.weight
# deformable_alignment.feature_head.1.1.model.1.conv.weight
# deformable_alignment.feature_head.1.1.model.1.norm.weight
# deformable_alignment.feature_head.1.1.model.1.norm.weight
# deformable_alignment.feature_head.1.1.model.1.norm.bias
# deformable_alignment.feature_head.1.1.model.1.norm.bias
# deformable_alignment.feature_head.1.1.model.1.norm.running_mean
# deformable_alignment.feature_head.1.1.model.1.norm.running_mean
# deformable_alignment.feature_head.1.1.model.1.norm.running_var
# deformable_alignment.feature_head.1.1.model.1.norm.running_var
# deformable_alignment.feature_head.1.1.model.1.norm.num_batches_tracked
# deformable_alignment.feature_head.1.1.model.1.norm.num_batches_tracked
# deformable_alignment.feature_head.1.1.model.2.conv.weight
# deformable_alignment.feature_head.1.1.model.2.conv.weight
# deformable_alignment.feature_head.1.1.model.2.norm.weight
# deformable_alignment.feature_head.1.1.model.2.norm.weight
# deformable_alignment.feature_head.1.1.model.2.norm.bias
# deformable_alignment.feature_head.1.1.model.2.norm.bias
# deformable_alignment.feature_head.1.1.model.2.norm.running_mean
# deformable_alignment.feature_head.1.1.model.2.norm.running_mean
# deformable_alignment.feature_head.1.1.model.2.norm.running_var
# deformable_alignment.feature_head.1.1.model.2.norm.running_var
# deformable_alignment.feature_head.1.1.model.2.norm.num_batches_tracked
# deformable_alignment.feature_head.1.1.model.2.norm.num_batches_tracked
# deformable_alignment.feature_head.1.2.weight
# deformable_alignment.feature_head.1.2.weight
# deformable_alignment.feature_head.1.3.weight
# deformable_alignment.feature_head.1.3.weight
# deformable_alignment.feature_head.1.3.bias
# deformable_alignment.feature_head.1.3.bias
# deformable_alignment.feature_head.1.3.running_mean
# deformable_alignment.feature_head.1.3.running_mean
# deformable_alignment.feature_head.1.3.running_var
# deformable_alignment.feature_head.1.3.running_var
# deformable_alignment.feature_head.1.3.num_batches_tracked
# deformable_alignment.feature_head.1.3.num_batches_tracked
# deformable_alignment.feature_head.1.5.weight
# deformable_alignment.feature_head.1.5.weight
# deformable_alignment.feature_head.1.5.bias
# deformable_alignment.feature_head.1.5.bias
# deformable_alignment.feature_head.2.1.model.0.conv.weight
# deformable_alignment.feature_head.2.1.model.0.conv.weight
# deformable_alignment.feature_head.2.1.model.0.norm.weight
# deformable_alignment.feature_head.2.1.model.0.norm.weight
# deformable_alignment.feature_head.2.1.model.0.norm.bias
# deformable_alignment.feature_head.2.1.model.0.norm.bias
# deformable_alignment.feature_head.2.1.model.0.norm.running_mean
# deformable_alignment.feature_head.2.1.model.0.norm.running_mean
# deformable_alignment.feature_head.2.1.model.0.norm.running_var
# deformable_alignment.feature_head.2.1.model.0.norm.running_var
# deformable_alignment.feature_head.2.1.model.0.norm.num_batches_tracked
# deformable_alignment.feature_head.2.1.model.0.norm.num_batches_tracked
# deformable_alignment.feature_head.2.1.model.1.conv.weight
# deformable_alignment.feature_head.2.1.model.1.conv.weight
# deformable_alignment.feature_head.2.1.model.1.norm.weight
# deformable_alignment.feature_head.2.1.model.1.norm.weight
# deformable_alignment.feature_head.2.1.model.1.norm.bias
# deformable_alignment.feature_head.2.1.model.1.norm.bias
# deformable_alignment.feature_head.2.1.model.1.norm.running_mean
# deformable_alignment.feature_head.2.1.model.1.norm.running_mean
# deformable_alignment.feature_head.2.1.model.1.norm.running_var
# deformable_alignment.feature_head.2.1.model.1.norm.running_var
# deformable_alignment.feature_head.2.1.model.1.norm.num_batches_tracked
# deformable_alignment.feature_head.2.1.model.1.norm.num_batches_tracked
# deformable_alignment.feature_head.2.1.model.2.conv.weight
# deformable_alignment.feature_head.2.1.model.2.conv.weight
# deformable_alignment.feature_head.2.1.model.2.norm.weight
# deformable_alignment.feature_head.2.1.model.2.norm.weight
# deformable_alignment.feature_head.2.1.model.2.norm.bias
# deformable_alignment.feature_head.2.1.model.2.norm.bias
# deformable_alignment.feature_head.2.1.model.2.norm.running_mean
# deformable_alignment.feature_head.2.1.model.2.norm.running_mean
# deformable_alignment.feature_head.2.1.model.2.norm.running_var
# deformable_alignment.feature_head.2.1.model.2.norm.running_var
# deformable_alignment.feature_head.2.1.model.2.norm.num_batches_tracked
# deformable_alignment.feature_head.2.1.model.2.norm.num_batches_tracked
# deformable_alignment.feature_head.2.2.weight
# deformable_alignment.feature_head.2.2.weight
# deformable_alignment.feature_head.2.3.weight
# deformable_alignment.feature_head.2.3.weight
# deformable_alignment.feature_head.2.3.bias
# deformable_alignment.feature_head.2.3.bias
# deformable_alignment.feature_head.2.3.running_mean
# deformable_alignment.feature_head.2.3.running_mean
# deformable_alignment.feature_head.2.3.running_var
# deformable_alignment.feature_head.2.3.running_var
# deformable_alignment.feature_head.2.3.num_batches_tracked
# deformable_alignment.feature_head.2.3.num_batches_tracked
# deformable_alignment.feature_head.2.5.weight
# deformable_alignment.feature_head.2.5.weight
# deformable_alignment.feature_head.2.5.bias
# deformable_alignment.feature_head.2.5.bias
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.0.0.weight
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.0.0.weight
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.0.0.bias
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.0.0.bias
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.1.0.weight
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.1.0.weight
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.1.0.bias
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.1.0.bias
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.2.0.weight
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.2.0.weight
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.2.0.bias
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.column.2.0.bias
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.offset_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.offset_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.offset_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.0.offset_conv.offset_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.0.modulator_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.0.modulator_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.0.modulator_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.0.modulator_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.0.regular_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.0.regular_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.0.0.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.0.0.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.0.0.bias
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.0.0.bias
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.1.0.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.1.0.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.1.0.bias
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.1.0.bias
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.2.0.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.2.0.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.2.0.bias
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.column.2.0.bias
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.offset_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.offset_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.offset_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.1.offset_conv.offset_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.1.modulator_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.1.modulator_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.1.modulator_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.1.modulator_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.1.regular_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.1.regular_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.0.0.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.0.0.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.0.0.bias
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.0.0.bias
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.1.0.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.1.0.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.1.0.bias
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.1.0.bias
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.2.0.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.2.0.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.2.0.bias
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.column.2.0.bias
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.offset_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.offset_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.offset_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.2.offset_conv.offset_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.2.modulator_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.2.modulator_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.2.modulator_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.2.modulator_conv.bias
# deformable_alignment.multi_scale_dcn_alignment.2.regular_conv.weight
# deformable_alignment.multi_scale_dcn_alignment.2.regular_conv.weight
# deformable_alignment.weight_conv.0.model.0.conv.weight
# deformable_alignment.weight_conv.0.model.0.conv.weight
# deformable_alignment.weight_conv.0.model.0.norm.weight
# deformable_alignment.weight_conv.0.model.0.norm.weight
# deformable_alignment.weight_conv.0.model.0.norm.bias
# deformable_alignment.weight_conv.0.model.0.norm.bias
# deformable_alignment.weight_conv.0.model.0.norm.running_mean
# deformable_alignment.weight_conv.0.model.0.norm.running_mean
# deformable_alignment.weight_conv.0.model.0.norm.running_var
# deformable_alignment.weight_conv.0.model.0.norm.running_var
# deformable_alignment.weight_conv.0.model.0.norm.num_batches_tracked
# deformable_alignment.weight_conv.0.model.0.norm.num_batches_tracked
# deformable_alignment.weight_conv.0.model.1.conv.weight
# deformable_alignment.weight_conv.0.model.1.conv.weight
# deformable_alignment.weight_conv.0.model.1.norm.weight
# deformable_alignment.weight_conv.0.model.1.norm.weight
# deformable_alignment.weight_conv.0.model.1.norm.bias
# deformable_alignment.weight_conv.0.model.1.norm.bias
# deformable_alignment.weight_conv.0.model.1.norm.running_mean
# deformable_alignment.weight_conv.0.model.1.norm.running_mean
# deformable_alignment.weight_conv.0.model.1.norm.running_var
# deformable_alignment.weight_conv.0.model.1.norm.running_var
# deformable_alignment.weight_conv.0.model.1.norm.num_batches_tracked
# deformable_alignment.weight_conv.0.model.1.norm.num_batches_tracked
# deformable_alignment.weight_conv.0.model.2.conv.weight
# deformable_alignment.weight_conv.0.model.2.conv.weight
# deformable_alignment.weight_conv.0.model.2.norm.weight
# deformable_alignment.weight_conv.0.model.2.norm.weight
# deformable_alignment.weight_conv.0.model.2.norm.bias
# deformable_alignment.weight_conv.0.model.2.norm.bias
# deformable_alignment.weight_conv.0.model.2.norm.running_mean
# deformable_alignment.weight_conv.0.model.2.norm.running_mean
# deformable_alignment.weight_conv.0.model.2.norm.running_var
# deformable_alignment.weight_conv.0.model.2.norm.running_var
# deformable_alignment.weight_conv.0.model.2.norm.num_batches_tracked
# deformable_alignment.weight_conv.0.model.2.norm.num_batches_tracked
# deformable_alignment.weight_conv.0.downsample.conv.weight
# deformable_alignment.weight_conv.0.downsample.conv.weight
# deformable_alignment.weight_conv.0.downsample.norm.weight
# deformable_alignment.weight_conv.0.downsample.norm.weight
# deformable_alignment.weight_conv.0.downsample.norm.bias
# deformable_alignment.weight_conv.0.downsample.norm.bias
# deformable_alignment.weight_conv.0.downsample.norm.running_mean
# deformable_alignment.weight_conv.0.downsample.norm.running_mean
# deformable_alignment.weight_conv.0.downsample.norm.running_var
# deformable_alignment.weight_conv.0.downsample.norm.running_var
# deformable_alignment.weight_conv.0.downsample.norm.num_batches_tracked
# deformable_alignment.weight_conv.0.downsample.norm.num_batches_tracked
# deformable_alignment.weight_conv.1.model.0.conv.weight
# deformable_alignment.weight_conv.1.model.0.conv.weight
# deformable_alignment.weight_conv.1.model.0.norm.weight
# deformable_alignment.weight_conv.1.model.0.norm.weight
# deformable_alignment.weight_conv.1.model.0.norm.bias
# deformable_alignment.weight_conv.1.model.0.norm.bias
# deformable_alignment.weight_conv.1.model.0.norm.running_mean
# deformable_alignment.weight_conv.1.model.0.norm.running_mean
# deformable_alignment.weight_conv.1.model.0.norm.running_var
# deformable_alignment.weight_conv.1.model.0.norm.running_var
# deformable_alignment.weight_conv.1.model.0.norm.num_batches_tracked
# deformable_alignment.weight_conv.1.model.0.norm.num_batches_tracked
# deformable_alignment.weight_conv.1.model.1.conv.weight
# deformable_alignment.weight_conv.1.model.1.conv.weight
# deformable_alignment.weight_conv.1.model.1.norm.weight
# deformable_alignment.weight_conv.1.model.1.norm.weight
# deformable_alignment.weight_conv.1.model.1.norm.bias
# deformable_alignment.weight_conv.1.model.1.norm.bias
# deformable_alignment.weight_conv.1.model.1.norm.running_mean
# deformable_alignment.weight_conv.1.model.1.norm.running_mean
# deformable_alignment.weight_conv.1.model.1.norm.running_var
# deformable_alignment.weight_conv.1.model.1.norm.running_var
# deformable_alignment.weight_conv.1.model.1.norm.num_batches_tracked
# deformable_alignment.weight_conv.1.model.1.norm.num_batches_tracked
# deformable_alignment.weight_conv.1.model.2.conv.weight
# deformable_alignment.weight_conv.1.model.2.conv.weight
# deformable_alignment.weight_conv.1.model.2.norm.weight
# deformable_alignment.weight_conv.1.model.2.norm.weight
# deformable_alignment.weight_conv.1.model.2.norm.bias
# deformable_alignment.weight_conv.1.model.2.norm.bias
# deformable_alignment.weight_conv.1.model.2.norm.running_mean
# deformable_alignment.weight_conv.1.model.2.norm.running_mean
# deformable_alignment.weight_conv.1.model.2.norm.running_var
# deformable_alignment.weight_conv.1.model.2.norm.running_var
# deformable_alignment.weight_conv.1.model.2.norm.num_batches_tracked
# deformable_alignment.weight_conv.1.model.2.norm.num_batches_tracked
# deformable_alignment.weight_conv.1.downsample.conv.weight
# deformable_alignment.weight_conv.1.downsample.conv.weight
# deformable_alignment.weight_conv.1.downsample.norm.weight
# deformable_alignment.weight_conv.1.downsample.norm.weight
# deformable_alignment.weight_conv.1.downsample.norm.bias
# deformable_alignment.weight_conv.1.downsample.norm.bias
# deformable_alignment.weight_conv.1.downsample.norm.running_mean
# deformable_alignment.weight_conv.1.downsample.norm.running_mean
# deformable_alignment.weight_conv.1.downsample.norm.running_var
# deformable_alignment.weight_conv.1.downsample.norm.running_var
# deformable_alignment.weight_conv.1.downsample.norm.num_batches_tracked
# deformable_alignment.weight_conv.1.downsample.norm.num_batches_tracked
# deformable_alignment.weight_conv.2.model.0.conv.weight
# deformable_alignment.weight_conv.2.model.0.conv.weight
# deformable_alignment.weight_conv.2.model.0.norm.weight
# deformable_alignment.weight_conv.2.model.0.norm.weight
# deformable_alignment.weight_conv.2.model.0.norm.bias
# deformable_alignment.weight_conv.2.model.0.norm.bias
# deformable_alignment.weight_conv.2.model.0.norm.running_mean
# deformable_alignment.weight_conv.2.model.0.norm.running_mean
# deformable_alignment.weight_conv.2.model.0.norm.running_var
# deformable_alignment.weight_conv.2.model.0.norm.running_var
# deformable_alignment.weight_conv.2.model.0.norm.num_batches_tracked
# deformable_alignment.weight_conv.2.model.0.norm.num_batches_tracked
# deformable_alignment.weight_conv.2.model.1.conv.weight
# deformable_alignment.weight_conv.2.model.1.conv.weight
# deformable_alignment.weight_conv.2.model.1.norm.weight
# deformable_alignment.weight_conv.2.model.1.norm.weight
# deformable_alignment.weight_conv.2.model.1.norm.bias
# deformable_alignment.weight_conv.2.model.1.norm.bias
# deformable_alignment.weight_conv.2.model.1.norm.running_mean
# deformable_alignment.weight_conv.2.model.1.norm.running_mean
# deformable_alignment.weight_conv.2.model.1.norm.running_var
# deformable_alignment.weight_conv.2.model.1.norm.running_var
# deformable_alignment.weight_conv.2.model.1.norm.num_batches_tracked
# deformable_alignment.weight_conv.2.model.1.norm.num_batches_tracked
# deformable_alignment.weight_conv.2.model.2.conv.weight
# deformable_alignment.weight_conv.2.model.2.conv.weight
# deformable_alignment.weight_conv.2.model.2.norm.weight
# deformable_alignment.weight_conv.2.model.2.norm.weight
# deformable_alignment.weight_conv.2.model.2.norm.bias
# deformable_alignment.weight_conv.2.model.2.norm.bias
# deformable_alignment.weight_conv.2.model.2.norm.running_mean
# deformable_alignment.weight_conv.2.model.2.norm.running_mean
# deformable_alignment.weight_conv.2.model.2.norm.running_var
# deformable_alignment.weight_conv.2.model.2.norm.running_var
# deformable_alignment.weight_conv.2.model.2.norm.num_batches_tracked
# deformable_alignment.weight_conv.2.model.2.norm.num_batches_tracked
# deformable_alignment.weight_conv.2.downsample.conv.weight
# deformable_alignment.weight_conv.2.downsample.conv.weight
# deformable_alignment.weight_conv.2.downsample.norm.weight
# deformable_alignment.weight_conv.2.downsample.norm.weight
# deformable_alignment.weight_conv.2.downsample.norm.bias
# deformable_alignment.weight_conv.2.downsample.norm.bias
# deformable_alignment.weight_conv.2.downsample.norm.running_mean
# deformable_alignment.weight_conv.2.downsample.norm.running_mean
# deformable_alignment.weight_conv.2.downsample.norm.running_var
# deformable_alignment.weight_conv.2.downsample.norm.running_var
# deformable_alignment.weight_conv.2.downsample.norm.num_batches_tracked
# deformable_alignment.weight_conv.2.downsample.norm.num_batches_tracked
# mask_predict_layer.1.model.0.conv.weight
# mask_predict_layer.1.model.0.conv.weight
# mask_predict_layer.1.model.0.norm.weight
# mask_predict_layer.1.model.0.norm.weight
# mask_predict_layer.1.model.0.norm.bias
# mask_predict_layer.1.model.0.norm.bias
# mask_predict_layer.1.model.0.norm.running_mean
# mask_predict_layer.1.model.0.norm.running_mean
# mask_predict_layer.1.model.0.norm.running_var
# mask_predict_layer.1.model.0.norm.running_var
# mask_predict_layer.1.model.0.norm.num_batches_tracked
# mask_predict_layer.1.model.0.norm.num_batches_tracked
# mask_predict_layer.1.model.1.conv.weight
# mask_predict_layer.1.model.1.conv.weight
# mask_predict_layer.1.model.1.norm.weight
# mask_predict_layer.1.model.1.norm.weight
# mask_predict_layer.1.model.1.norm.bias
# mask_predict_layer.1.model.1.norm.bias
# mask_predict_layer.1.model.1.norm.running_mean
# mask_predict_layer.1.model.1.norm.running_mean
# mask_predict_layer.1.model.1.norm.running_var
# mask_predict_layer.1.model.1.norm.running_var
# mask_predict_layer.1.model.1.norm.num_batches_tracked
# mask_predict_layer.1.model.1.norm.num_batches_tracked
# mask_predict_layer.1.model.2.conv.weight
# mask_predict_layer.1.model.2.conv.weight
# mask_predict_layer.1.model.2.norm.weight
# mask_predict_layer.1.model.2.norm.weight
# mask_predict_layer.1.model.2.norm.bias
# mask_predict_layer.1.model.2.norm.bias
# mask_predict_layer.1.model.2.norm.running_mean
# mask_predict_layer.1.model.2.norm.running_mean
# mask_predict_layer.1.model.2.norm.running_var
# mask_predict_layer.1.model.2.norm.running_var
# mask_predict_layer.1.model.2.norm.num_batches_tracked
# mask_predict_layer.1.model.2.norm.num_batches_tracked
# mask_predict_layer.1.downsample.conv.weight
# mask_predict_layer.1.downsample.conv.weight
# mask_predict_layer.1.downsample.norm.weight
# mask_predict_layer.1.downsample.norm.weight
# mask_predict_layer.1.downsample.norm.bias
# mask_predict_layer.1.downsample.norm.bias
# mask_predict_layer.1.downsample.norm.running_mean
# mask_predict_layer.1.downsample.norm.running_mean
# mask_predict_layer.1.downsample.norm.running_var
# mask_predict_layer.1.downsample.norm.running_var
# mask_predict_layer.1.downsample.norm.num_batches_tracked
# mask_predict_layer.1.downsample.norm.num_batches_tracked
# mask_predict_layer.2.model.0.conv.weight
# mask_predict_layer.2.model.0.conv.weight
# mask_predict_layer.2.model.0.norm.weight
# mask_predict_layer.2.model.0.norm.weight
# mask_predict_layer.2.model.0.norm.bias
# mask_predict_layer.2.model.0.norm.bias
# mask_predict_layer.2.model.0.norm.running_mean
# mask_predict_layer.2.model.0.norm.running_mean
# mask_predict_layer.2.model.0.norm.running_var
# mask_predict_layer.2.model.0.norm.running_var
# mask_predict_layer.2.model.0.norm.num_batches_tracked
# mask_predict_layer.2.model.0.norm.num_batches_tracked
# mask_predict_layer.2.model.1.conv.weight
# mask_predict_layer.2.model.1.conv.weight
# mask_predict_layer.2.model.1.norm.weight
# mask_predict_layer.2.model.1.norm.weight
# mask_predict_layer.2.model.1.norm.bias
# mask_predict_layer.2.model.1.norm.bias
# mask_predict_layer.2.model.1.norm.running_mean
# mask_predict_layer.2.model.1.norm.running_mean
# mask_predict_layer.2.model.1.norm.running_var
# mask_predict_layer.2.model.1.norm.running_var
# mask_predict_layer.2.model.1.norm.num_batches_tracked
# mask_predict_layer.2.model.1.norm.num_batches_tracked
# mask_predict_layer.2.model.2.conv.weight
# mask_predict_layer.2.model.2.conv.weight
# mask_predict_layer.2.model.2.norm.weight
# mask_predict_layer.2.model.2.norm.weight
# mask_predict_layer.2.model.2.norm.bias
# mask_predict_layer.2.model.2.norm.bias
# mask_predict_layer.2.model.2.norm.running_mean
# mask_predict_layer.2.model.2.norm.running_mean
# mask_predict_layer.2.model.2.norm.running_var
# mask_predict_layer.2.model.2.norm.running_var
# mask_predict_layer.2.model.2.norm.num_batches_tracked
# mask_predict_layer.2.model.2.norm.num_batches_tracked
# mask_predict_layer.2.downsample.conv.weight
# mask_predict_layer.2.downsample.conv.weight
# mask_predict_layer.2.downsample.norm.weight
# mask_predict_layer.2.downsample.norm.weight
# mask_predict_layer.2.downsample.norm.bias
# mask_predict_layer.2.downsample.norm.bias
# mask_predict_layer.2.downsample.norm.running_mean
# mask_predict_layer.2.downsample.norm.running_mean
# mask_predict_layer.2.downsample.norm.running_var
# mask_predict_layer.2.downsample.norm.running_var
# mask_predict_layer.2.downsample.norm.num_batches_tracked
# mask_predict_layer.2.downsample.norm.num_batches_tracked
# mask_predict_layer.3.weight
# mask_predict_layer.3.weight
# mask_predict_layer.4.weight
# mask_predict_layer.4.weight
# mask_predict_layer.4.bias
# mask_predict_layer.4.bias
# mask_predict_layer.4.running_mean
# mask_predict_layer.4.running_mean
# mask_predict_layer.4.running_var
# mask_predict_layer.4.running_var
# mask_predict_layer.4.num_batches_tracked
# mask_predict_layer.4.num_batches_tracked
# mask_predict_layer.5.weight
# mask_predict_layer.5.weight
# mask_predict_layer.5.bias
# mask_predict_layer.5.bias
# mask_predict_layer.6.weight
# mask_predict_layer.6.weight
# mask_predict_layer.6.bias
# mask_predict_layer.6.bias
# mask_predict_layer.6.running_mean
# mask_predict_layer.6.running_mean
# mask_predict_layer.6.running_var
# mask_predict_layer.6.running_var
# mask_predict_layer.6.num_batches_tracked
# mask_predict_layer.6.num_batches_tracked
# mask_predict_layer.7.weight
# mask_predict_layer.7.weight
# mask_predict_layer.8.weight
# mask_predict_layer.8.weight
# mask_predict_layer.8.bias
# mask_predict_layer.8.bias
# mask_predict_layer.8.running_mean
# mask_predict_layer.8.running_mean
# mask_predict_layer.8.running_var
# mask_predict_layer.8.running_var
# mask_predict_layer.8.num_batches_tracked
# mask_predict_layer.8.num_batches_tracked
# mask_predict_layer.9.weight
# mask_predict_layer.9.weight
# mask_predict_layer.9.bias
# mask_predict_layer.9.bias
# confidence_predict_layer.0.weight
# ASAM.0.weight
# confidence_predict_layer.0.bias
# ASAM.0.bias
# confidence_predict_layer.1.weight
# ASAM.1.weight
# confidence_predict_layer.1.bias
# ASAM.1.bias
# confidence_predict_layer.1.running_mean
# ASAM.1.running_mean
# confidence_predict_layer.1.running_var
# ASAM.1.running_var
# confidence_predict_layer.1.num_batches_tracked
# ASAM.1.num_batches_tracked
# confidence_predict_layer.3.weight
# ASAM.3.weight
# confidence_predict_layer.3.bias
# ASAM.3.bias
# confidence_predict_layer.4.weight
# ASAM.4.weight
# confidence_predict_layer.4.bias
# ASAM.4.bias
# confidence_predict_layer.4.running_mean
# ASAM.4.running_mean
# confidence_predict_layer.4.running_var
# ASAM.4.running_var
# confidence_predict_layer.4.num_batches_tracked
# ASAM.4.num_batches_tracked
# confidence_predict_layer.6.weight
# ASAM.6.weight
# confidence_predict_layer.6.bias
# ASAM.6.bias

# %%
import sys
sys.path.append('..')
from datasets.dataset import *

_,label = SENSE_ImgPath_and_Target()

# %%
from scipy.optimize import linear_sum_assignment
import numpy as np

cost = np.array([[4,1,3],
                [2,0,5],
                [3,2,2]])
r, c = linear_sum_assignment(cost)
print(r)
print(C)
